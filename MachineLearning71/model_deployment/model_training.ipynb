# %%
import pandas as pd
import numpy as np
import joblib

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score,confusion_matrix
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 5
#       1 import pandas as pd
#       2 import numpy as np
#       3 import joblib
#       4
# ----> 5 from sklearn.model_selection import train_test_split
#       6 from sklearn.ensemble import RandomForestClassifier
#       7 from sklearn.metrics import accuracy_score,confusion_matrix
#
# File ~/Downloads/PythonModules/ml/.venv/lib/python3.11/site-packages/sklearn/__init__.py:70
#
# File ~/Downloads/PythonModules/ml/.venv/lib/python3.11/site-packages/sklearn/base.py:20
#
# File ~/Downloads/PythonModules/ml/.venv/lib/python3.11/site-packages/sklearn/utils/__init__.py:9
#
# File ~/Downloads/PythonModules/ml/.venv/lib/python3.11/site-packages/sklearn/utils/_chunking.py:11
#
# File ~/Downloads/PythonModules/ml/.venv/lib/python3.11/site-packages/sklearn/utils/_param_validation.py:17
#
# File ~/Downloads/PythonModules/ml/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:24
#
# File ~/Downloads/PythonModules/ml/.venv/lib/python3.11/site-packages/sklearn/utils/_array_api.py:23
#
# File ~/Downloads/PythonModules/ml/.venv/lib/python3.11/site-packages/sklearn/utils/fixes.py:16
#
# File ~/Downloads/PythonModules/ml/.venv/lib/python3.11/site-packages/scipy/stats/__init__.py:628
#
# File ~/Downloads/PythonModules/ml/.venv/lib/python3.11/site-packages/scipy/stats/_stats_py.py:49
#
# File ~/Downloads/PythonModules/ml/.venv/lib/python3.11/site-packages/scipy/stats/distributions.py:10
#
# File ~/Downloads/PythonModules/ml/.venv/lib/python3.11/site-packages/scipy/stats/_continuous_distns.py:28
#
# ModuleNotFoundError: No module named 'scipy.stats._tukeylambda_stats'

# %%
# Load the data from file
data = pd.read_csv("data/data_banknote_authentication.txt",header=None)

# %%
#
data.columns = ["variance",'skewness','curtosis','entropy','target']
print(data.head())
# Out:
#    variance  skewness  curtosis  entropy  target
# 0   3.62160    8.6661   -2.8073 -0.44699       0
# 1   4.54590    8.1674   -2.4586 -1.46210       0
# 2   3.86600   -2.6383    1.9242  0.10645       0
# 3   3.45660    9.5228   -4.0112 -3.59440       0
# 4   0.32924   -4.4552    4.5718 -0.98880       0

# %%
X = data.drop('target',axis=1)
y = data['target']

# %%
X_train,X_test,y_train,y_test = train_test_split(
    X,
    y,
    random_state=42,
    stratify=y
)
